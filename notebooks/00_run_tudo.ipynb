# %% [markdown]
# ### Execução completa da pipeline
#
# Orquestra a execução de todos os notebooks na sequência correta. Em caso
# de falha em qualquer etapa, a execução é interrompida no ponto de falha.
#
# Pré-requisito: este notebook deve estar no mesmo nível das subpastas
# 00_setup, 01_bronze, 02_silver e 03_gold.

# %%
# %pip install openpyxl -q

# %%
# %run "./00_setup/00_setup_ambiente"

# %%
# %run "./01_bronze/01_bronze_ingestao"

# %%
# %run "./02_silver/02_silver_regioes"

# %%
# %run "./02_silver/03_silver_canais"

# %%
# %run "./02_silver/04_silver_produtos"

# %%
# %run "./02_silver/05_silver_vendedores"

# %%
# %run "./02_silver/06_silver_clientes"

# %%
# %run "./02_silver/07_silver_pedidos"

# %%
# %run "./02_silver/08_silver_entregas"

# %%
# %run "./02_silver/09_silver_ocorrencias"

# %%
# %run "./03_gold/10_gold_dimensoes"

# %%
# %run "./03_gold/11_gold_fact_pedido_item"

# %%
# %run "./03_gold/12_gold_fact_entrega_ocorrencia"

# %%
# %run "./03_gold/13_gold_exemplos_kpis"

# %%
print("Pipeline executada com sucesso.")
