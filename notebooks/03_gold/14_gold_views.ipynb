# %% [markdown]
# ### Gold - views e evidência de saída
#
# Cria views SQL sobre as tabelas físicas da camada Gold, para consumo
# direto via SQL Editor ou ferramenta de BI sem precisar referenciar o
# schema completo. Também imprime as contagens finais de cada tabela como
# registro de execução.

# %%
# %run "../00_setup/00_setup_ambiente"

# %%
# %sql
CREATE OR REPLACE VIEW case_dados.vw_dim_cliente AS
SELECT * FROM case_dados.dim_cliente

# %%
# %sql
CREATE OR REPLACE VIEW case_dados.vw_dim_vendedor AS
SELECT * FROM case_dados.dim_vendedor

# %%
# %sql
CREATE OR REPLACE VIEW case_dados.vw_dim_produto AS
SELECT * FROM case_dados.dim_produto

# %%
# %sql
CREATE OR REPLACE VIEW case_dados.vw_dim_canal AS
SELECT * FROM case_dados.dim_canal

# %%
# %sql
CREATE OR REPLACE VIEW case_dados.vw_dim_regiao AS
SELECT * FROM case_dados.dim_regiao

# %%
# %sql
CREATE OR REPLACE VIEW case_dados.vw_dim_tempo AS
SELECT * FROM case_dados.dim_tempo

# %%
# %sql
CREATE OR REPLACE VIEW case_dados.vw_fact_pedido_item AS
SELECT * FROM case_dados.fact_pedido_item

# %%
# %sql
CREATE OR REPLACE VIEW case_dados.vw_fact_entrega AS
SELECT * FROM case_dados.fact_entrega

# %%
# %sql
CREATE OR REPLACE VIEW case_dados.vw_fact_ocorrencia AS
SELECT * FROM case_dados.fact_ocorrencia

# %% [markdown]
# #### Contagem final por tabela (evidência de execução)

# %%
tabelas_gold = [
    "dim_cliente", "dim_vendedor", "dim_produto", "dim_canal", "dim_regiao", "dim_tempo",
    "fact_pedido_item", "fact_entrega", "fact_ocorrencia",
]
resumo = [(t, spark.table(f"{schema_name}.{t}").count()) for t in tabelas_gold]
df_resumo = spark.createDataFrame(resumo, ["tabela", "registros"])
display(df_resumo)

# %% [markdown]
# #### Amostra de cada view criada

# %%
display(spark.table("case_dados.vw_dim_cliente").limit(5))

# %%
display(spark.table("case_dados.vw_dim_vendedor").limit(5))

# %%
display(spark.table("case_dados.vw_dim_produto").limit(5))

# %%
display(spark.table("case_dados.vw_dim_canal").limit(5))

# %%
display(spark.table("case_dados.vw_dim_regiao"))

# %%
display(spark.table("case_dados.vw_dim_tempo").limit(5))

# %%
display(spark.table("case_dados.vw_fact_pedido_item").limit(10))

# %%
display(spark.table("case_dados.vw_fact_entrega").limit(10))

# %%
display(spark.table("case_dados.vw_fact_ocorrencia").limit(10))
